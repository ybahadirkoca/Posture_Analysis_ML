# %%
# ================================================================
# KNN 
# ================================================================

import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, LeaveOneOut
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, balanced_accuracy_score, f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.pipeline import Pipeline
import statsmodels.stats.proportion as smp
from itertools import product
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# -----------------------
# 0) Ayarlar
# -----------------------
FILE_PATH = "ML_Analysis_V3.xlsx"   # <-- kendi yolun
TARGETS = ["Cervical Lordosis Risk","Kyphosis Risk","Lumbar Lordosis Risk","Scoliosis Risk"]
RUN_LOSO = True          # hızlı istersen False yap
TUNING_SCORING = "balanced_accuracy"  # alternatif: "f1_macro"

# -----------------------
# 1) Veri seti
# -----------------------
df = pd.read_excel(FILE_PATH, sheet_name="Sheet1")
feature_cols = [c for c in df.columns if c not in TARGETS]

# -----------------------
# 2) Yardımcılar
# -----------------------
def make_adaptive_sampler(y_train):
    counts = y_train.value_counts().to_dict()
    minority_n = min(counts.get(0, 0), counts.get(1, 0))
    if minority_n >= 3:
        k = max(1, min(5, minority_n - 1))
        return SMOTE(k_neighbors=k, random_state=42)
    else:
        return RandomOverSampler(random_state=42)

def get_stratified_cv(y, desired_splits):
    minority_n = y.value_counts().min()
    n_splits = max(2, min(desired_splits, int(minority_n))) if int(minority_n) > 1 else 2
    return StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42), n_splits

def fit_predict_one_fold_knn(X_train, y_train, X_test, knn_params):
    sampler = make_adaptive_sampler(y_train)
    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('sampler', sampler),
        ('knn', KNeighborsClassifier(**knn_params))
    ])
    pipe.fit(X_train, y_train)
    return pipe.predict(X_test)

# -----------------------
# 3) Global tuning (hızlı)
# -----------------------
def global_tune_knn(X, y, desired_splits=5, scoring="balanced_accuracy"):
    skf, used_splits = get_stratified_cv(y, desired_splits)

    # Param grid
    grid = {
        "n_neighbors": [1,3,5,7,9],
        "weights": ["uniform", "distance"],
        "metric": ["minkowski"],
        "p": [1, 2]  # 1: manhattan, 2: euclidean
    }

    keys = list(grid.keys()); vals = [grid[k] for k in keys]
    best_score, best_params = -np.inf, None

    for combo in product(*vals):
        p_dict = dict(zip(keys, combo))
        fold_scores = []
        for tr, va in skf.split(X, y):
            X_tr, X_va = X.iloc[tr], X.iloc[va]
            y_tr, y_va = y.iloc[tr], y.iloc[va]
            sampler = make_adaptive_sampler(y_tr)
            pipe = Pipeline([
                ('scaler', StandardScaler()),
                ('sampler', sampler),
                ('knn', KNeighborsClassifier(**p_dict))
            ])
            pipe.fit(X_tr, y_tr)
            pred = pipe.predict(X_va)
            s = balanced_accuracy_score(y_va, pred) if scoring=="balanced_accuracy" \
                else f1_score(y_va, pred, average="macro")
            fold_scores.append(s)
        m = np.mean(fold_scores)
        if m > best_score:
            best_score, best_params = m, p_dict

    return best_params, best_score, used_splits

# -----------------------
# 4) Değerlendirme
# -----------------------
def evaluate_scheme_knn(X, y, splitter, scheme_name, knn_params):
    splits = splitter.split(X, y) if isinstance(splitter, StratifiedKFold) else splitter.split(X)
    y_true, y_pred = [], []
    for tr, te in splits:
        X_tr, X_te = X.iloc[tr], X.iloc[te]
        y_tr, y_te = y.iloc[tr], y.iloc[te]
        pred = fit_predict_one_fold_knn(X_tr, y_tr, X_te, knn_params)
        y_true.extend(y_te); y_pred.extend(pred)
    rep = classification_report(y_true, y_pred, output_dict=True, zero_division=0)
    cm  = confusion_matrix(y_true, y_pred, labels=[0,1])
    tn, fp, fn, tp = cm.ravel()
    acc = accuracy_score(y_true, y_pred)
    n = len(y_true); k = int((np.array(y_true) == np.array(y_pred)).sum())
    ci_lo, ci_hi = smp.proportion_confint(k, n, alpha=0.05, method='wilson')
    return {
        "Scheme": scheme_name,
        "Accuracy": acc,
        "95% CI Low": ci_lo, "95% CI High": ci_hi,
        "Weighted Precision": rep["weighted avg"]["precision"],
        "Weighted Recall": rep["weighted avg"]["recall"],
        "Weighted F1": rep["weighted avg"]["f1-score"],
        "Support": int(cm.sum()), "TN": int(tn), "FP": int(fp), "FN": int(fn), "TP": int(tp)
    }

# -----------------------
# 5) Çalıştır
# -----------------------
all_rows, tuning_rows = [], []

for target in TARGETS:
    print(f"\n=== KNN Tuning & Evaluation for: {target} ===")
    X = df[feature_cols].copy(); y = df[target].copy()

    best_params, best_cv, used_splits = global_tune_knn(X, y, desired_splits=5, scoring=TUNING_SCORING)
    print(f"Best params (Stratified {used_splits}-Fold): {best_params} | Mean CV ({TUNING_SCORING}): {round(best_cv,3)}")
    tuning_rows.append({"Target": target, "CV (tuning)": f"Stratified {used_splits}-Fold",
                        "Best Params": best_params, f"Mean CV ({TUNING_SCORING})": round(best_cv,3)})

    if RUN_LOSO:
        row_loso = evaluate_scheme_knn(X, y, LeaveOneOut(), "LOSO", best_params)
        all_rows.append({"Target": target, **row_loso})

    cv5, used5   = get_stratified_cv(y, 5)
    cv10, used10 = get_stratified_cv(y, 10)

    row_s5  = evaluate_scheme_knn(X, y, cv5,  f"Stratified {used5}-Fold",  best_params)
    row_s10 = evaluate_scheme_knn(X, y, cv10, f"Stratified {used10}-Fold", best_params)
    all_rows += [{"Target": target, **row_s5}, {"Target": target, **row_s10}]

summary_knn = pd.DataFrame(all_rows)
tuning_summary = pd.DataFrame(tuning_rows)

print("\n=== KNN – Master Table (LOSO + adaptive 5/10-Fold) ===")
print(summary_knn)
print("\n=== KNN – Tuning Summary ===")
print(tuning_summary)

# İstersen CSV:
# summary_knn.to_csv("KNN_Scaled_AdaptiveOversampling_AdaptiveCV_AllTargets.csv", index=False)
# tuning_summary.to_csv("KNN_Tuning_Summary.csv", index=False)
# Out:
# === KNN Tuning & Evaluation for: Cervical Lordosis Risk ===
# Best params (Stratified 5-Fold): {'n_neighbors': 7, 'weights': 'distance', 'metric': 'minkowski', 'p': 1} | Mean CV (balanced_accuracy): 0.86
#
# === KNN Tuning & Evaluation for: Kyphosis Risk ===
# Best params (Stratified 5-Fold): {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'minkowski', 'p': 2} | Mean CV (balanced_accuracy): 0.758
#
# === KNN Tuning & Evaluation for: Lumbar Lordosis Risk ===
# Best params (Stratified 4-Fold): {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'minkowski', 'p': 2} | Mean CV (balanced_accuracy): 0.679
#
# === KNN Tuning & Evaluation for: Scoliosis Risk ===
# Best params (Stratified 5-Fold): {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'minkowski', 'p': 1} | Mean CV (balanced_accuracy): 0.667
#
# === KNN – Master Table (LOSO + adaptive 5/10-Fold) ===
#                     Target              Scheme  Accuracy  95% CI Low  \
# 0   Cervical Lordosis Risk                LOSO  0.833333    0.664356
# 1   Cervical Lordosis Risk   Stratified 5-Fold  0.900000    0.743789
# 2   Cervical Lordosis Risk   Stratified 6-Fold  0.733333    0.555520
# 3            Kyphosis Risk                LOSO  0.700000    0.521242
# 4            Kyphosis Risk   Stratified 5-Fold  0.766667    0.590717
# 5            Kyphosis Risk  Stratified 10-Fold  0.700000    0.521242
# 6     Lumbar Lordosis Risk                LOSO  0.533333    0.361423
# 7     Lumbar Lordosis Risk   Stratified 4-Fold  0.600000    0.423204
# 8     Lumbar Lordosis Risk   Stratified 4-Fold  0.600000    0.423204
# 9           Scoliosis Risk                LOSO  0.633333    0.455136
# 10          Scoliosis Risk   Stratified 5-Fold  0.666667    0.487801
# 11          Scoliosis Risk  Stratified 10-Fold  0.533333    0.361423
#
#     95% CI High  Weighted Precision  Weighted Recall  Weighted F1  Support  \
# 0      0.926635            0.844720         0.833333     0.837971       30
# 1      0.965400            0.908075         0.900000     0.902782       30
# 2      0.858173            0.765909         0.733333     0.746584       30
# 3      0.833353            0.731100         0.700000     0.694949       30
# 4      0.882076            0.780694         0.766667     0.765888       30
# 5      0.833353            0.712217         0.700000     0.698999       30
# 6      0.697676            0.733333         0.533333     0.607576       30
# 7      0.754094            0.841071         0.600000     0.663492       30
# 8      0.754094            0.841071         0.600000     0.663492       30
# 9      0.781261            0.643056         0.633333     0.597090       30
# 10     0.807695            0.663477         0.666667     0.662037       30
# 11     0.697676            0.525040         0.533333     0.526852       30
#
#     TN  FP  FN  TP
# 0   21   3   2   4
# 1   22   2   1   5
# 2   19   5   3   3
# 3   12   2   7   9
# 4   12   2   5  11
# 5   11   3   6  10
# 6   15  11   3   1
# 7   15  11   1   3
# 8   15  11   1   3
# 9   15   2   9   4
# 10  13   4   6   7
# 11  11   6   8   5
#
# === KNN – Tuning Summary ===
#                    Target        CV (tuning)  \
# 0  Cervical Lordosis Risk  Stratified 5-Fold
# 1           Kyphosis Risk  Stratified 5-Fold
# 2    Lumbar Lordosis Risk  Stratified 4-Fold
# 3          Scoliosis Risk  Stratified 5-Fold
#
#                                          Best Params  \
# 0  {'n_neighbors': 7, 'weights': 'distance', 'met...
# 1  {'n_neighbors': 3, 'weights': 'uniform', 'metr...
# 2  {'n_neighbors': 5, 'weights': 'uniform', 'metr...
# 3  {'n_neighbors': 3, 'weights': 'uniform', 'metr...
#
#    Mean CV (balanced_accuracy)
# 0                        0.860
# 1                        0.758
# 2                        0.679
# 3                        0.667
